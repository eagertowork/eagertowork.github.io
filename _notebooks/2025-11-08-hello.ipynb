# %% [markdown]
# # "My First Fastpages Post"
# > This is a sample post using Jupyter Notebook
#
# - toc: true
# - badges: true
# - comments: true
# - categories: [fastpages, jupyter]

# %%
print("Hello")
# Out:
# Hello
